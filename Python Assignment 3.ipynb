# %%
#Pre-requisite
import pandas as pd
import numpy as np
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN',
'londON_StockhOlm',
'Budapest_PaRis', 'Brussels_londOn'],
'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
'12. Air France', '"Swiss Air"']})

# %%
#Question 1

df.loc[1,"FlightNumber"]=10055
df.loc[3,"FlightNumber"]=10075

df["FlightNumber"]=df["FlightNumber"].astype(int)

# %%
#Question 2
temp=df.copy()

for i in range(0,df.shape[0]):
    s=df["From_To"][i].split(sep="_")
    temp.loc[i,"From"]=s[0]
    temp.loc[i,"To"]=s[1]
    i=i+1
    
temp
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"
#
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
#Question 3

for i in range(0,df.shape[0]):
    s=df["From_To"][i].split(sep="_")
    temp.loc[i,"From"]=s[0].title()
    temp.loc[i,"To"]=s[1].title()
    i=i+1
temp
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"
#
#        From         To
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %%
#Question 4

df.drop("From_To",axis=1,inplace=True)

# %%
df2=pd.merge(df, temp,how='left',on=["Airline","FlightNumber"])

# %%
df2
# Out:
#    FlightNumber RecentDelays_x              Airline           From_To  \
# 0         10045       [23, 47]               KLM(!)      LoNDon_paris
# 1         10055             []    <Air France> (12)      MAdrid_miLAN
# 2         10065   [24, 43, 87]  (British Airways. )  londON_StockhOlm
# 3         10075           [13]       12. Air France    Budapest_PaRis
# 4         10085       [67, 32]          "Swiss Air"   Brussels_londOn
#
#   RecentDelays_y      From         To
# 0       [23, 47]    London      Paris
# 1             []    Madrid      Milan
# 2   [24, 43, 87]    London  Stockholm
# 3           [13]  Budapest      Paris
# 4       [67, 32]  Brussels     London

# %%
#question 5
df3=pd.DataFrame(df2['RecentDelays_x'].tolist())

# %%
delay=['delay_1','delay_2','delay_3']

# %%
df3.rename(columns={0:"delay_1",1:"delay_2",2:"delay_3"},inplace=True)

# %%
df3.iloc[2]
# Out:
# delay_1    24.0
# delay_2    43.0
# delay_3    87.0
# Name: 2, dtype: float64

# %%
df2=df2.join(df3)

# %%
df2
# Out:
#    FlightNumber RecentDelays_x              Airline           From_To  \
# 0         10045       [23, 47]               KLM(!)      LoNDon_paris
# 1         10055             []    <Air France> (12)      MAdrid_miLAN
# 2         10065   [24, 43, 87]  (British Airways. )  londON_StockhOlm
# 3         10075           [13]       12. Air France    Budapest_PaRis
# 4         10085       [67, 32]          "Swiss Air"   Brussels_londOn
#
#   RecentDelays_y      From         To  delay_1  delay_2  delay_3
# 0       [23, 47]    London      Paris     23.0     47.0      NaN
# 1             []    Madrid      Milan      NaN      NaN      NaN
# 2   [24, 43, 87]    London  Stockholm     24.0     43.0     87.0
# 3           [13]  Budapest      Paris     13.0      NaN      NaN
# 4       [67, 32]  Brussels     London     67.0     32.0      NaN
